# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Data Wrangling

#Import a sample CSV file

csv_df = pd.read_csv('sample.csv')

# %%
print(csv_df)
# Out:
#        policyID statecode           county  eq_site_limit  hu_site_limit  \
# 0        119736        FL      CLAY COUNTY       498960.0      498960.00
# 1        448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 2        206893        FL      CLAY COUNTY       190724.4      190724.40
# 3        333743        FL      CLAY COUNTY            0.0       79520.76
# 4        172534        FL      CLAY COUNTY            0.0      254281.50
# 5        785275        FL      CLAY COUNTY            0.0      515035.62
# 6        995932        FL      CLAY COUNTY            0.0    19260000.00
# 7        223488        FL      CLAY COUNTY       328500.0      328500.00
# 8        433512        FL      CLAY COUNTY       315000.0      315000.00
# 9        142071        FL      CLAY COUNTY       705600.0      705600.00
# 10       253816        FL      CLAY COUNTY       831498.3      831498.30
# 11       894922        FL      CLAY COUNTY            0.0       24059.09
# ...

# %%
csv_df.to_csv('sample.csv' index=False)
# Out:
#   File "<ipython-input-4-d7f6d506516a>", line 1
#     csv_df.to_csv('sample.csv' index=False)
#                                    ^
# SyntaxError: invalid syntax

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'C:\Users\timii\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
#Import xlsx file

excel_df = pd.read_excel('file_example.xls')
print(excel_df)
# Out:
#       Unnamed: 0 First Name   Last Name  Gender        Country  Age  \
# 0              1      Dulce       Abril  Female  United States   32
# 1              2       Mara   Hashimoto  Female  Great Britain   25
# 2              3     Philip        Gent    Male         France   36
# 3              4   Kathleen      Hanner  Female  United States   25
# 4              5    Nereida     Magwood  Female  United States   58
# 5              6     Gaston       Brumm    Male  United States   24
# 6              7       Etta        Hurn  Female  Great Britain   56
# 7              8    Earlean      Melgar  Female  United States   27
# 8              9   Vincenza     Weiland  Female  United States   40
# 9             10     Fallon     Winward  Female  Great Britain   28
# 10            11    Arcelia      Bouska  Female  Great Britain   39
# 11            12   Franklyn      Unknow    Male         France   38
# 12            13    Sherron    Ascencio  Female  Great Britain   32
# ...

# %%
excel_df.to_excel('file_example.xls')
print(excel_df)
# Out:
#       Unnamed: 0 First Name   Last Name  Gender        Country  Age  \
# 0              1      Dulce       Abril  Female  United States   32
# 1              2       Mara   Hashimoto  Female  Great Britain   25
# 2              3     Philip        Gent    Male         France   36
# 3              4   Kathleen      Hanner  Female  United States   25
# 4              5    Nereida     Magwood  Female  United States   58
# 5              6     Gaston       Brumm    Male  United States   24
# 6              7       Etta        Hurn  Female  Great Britain   56
# 7              8    Earlean      Melgar  Female  United States   27
# 8              9   Vincenza     Weiland  Female  United States   40
# 9             10     Fallon     Winward  Female  Great Britain   28
# 10            11    Arcelia      Bouska  Female  Great Britain   39
# 11            12   Franklyn      Unknow    Male         France   38
# 12            13    Sherron    Ascencio  Female  Great Britain   32
# ...

# %%
#Import files from webpage
html_df = pd.read_html('https://www.contextures.com/xlSampleData01.html')

# %%
print(html_df)
# Out:
# [             0        1         2        3      4         5        6
# 0    OrderDate   Region       Rep     Item  Units  UnitCost    Total
# 1     1/6/2019     East     Jones   Pencil     95      1.99   189.05
# 2    1/23/2019  Central    Kivell   Binder     50     19.99   999.50
# 3     2/9/2019  Central   Jardine   Pencil     36      4.99   179.64
# 4    2/26/2019  Central      Gill      Pen     27     19.99   539.73
# 5    3/15/2019     West   Sorvino   Pencil     56      2.99   167.44
# 6     4/1/2019     East     Jones   Binder     60      4.99   299.40
# 7    4/18/2019  Central   Andrews   Pencil     75      1.99   149.25
# 8     5/5/2019  Central   Jardine   Pencil     90      4.99   449.10
# 9    5/22/2019     West  Thompson   Pencil     32      1.99    63.68
# 10    6/8/2019     East     Jones   Binder     60      8.99   539.40
# 11   6/25/2019  Central    Morgan   Pencil     90      4.99   449.10
# 12   7/12/2019     East    Howard   Binder     29      1.99    57.71
# ...

# %%
#WORKING on Data provided

fuel_data = pd.read_csv('fuel_fe.csv', error_bad_lines = False)
fuel_data.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
#Check for missing values

fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
np.rows(fuel_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-440b7b2d0629> in <module>
# ----> 1 np.rows(fuel_data)
#
# AttributeError: module 'numpy' has no attribute 'rows'

# %%
#check for duplicate rows
fuel_data.duplicated().any()
# Out:
# False

# %%
print(fuel_data)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
print(fuel_data)

# %%
fuel_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
#use groupby to count the sum of each unique value in the fuel unit column
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11534
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
#fuel type code average fuel cost per unit burned

fuel_data.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].mean()
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
np.std(fuel_data)
Fuel_mmbtu_per_unit
# Out:
# utility_id_ferc1                7.417710e+01
# report_year                     7.025364e+00
# fuel_qty_burned                 9.117849e+06
# fuel_mmbtu_per_unit             1.060004e+01
# fuel_cost_per_unit_burned       2.854442e+03
# fuel_cost_per_unit_delivered    6.877476e+04
# fuel_cost_per_mmbtu             2.091506e+03
# dtype: float64

# %%
fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')

# %%
#check if missing values have been filled
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel_data.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
fuel_data.groupby('report_year')['fuel_cost_per_unit_delivered'].mean()
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
#group by the fuel type code year and print the first entries in all the groups formed

fuel_data.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                  f1_fuel_1994_12_1_0_7                 1         1994
# gas                  f1_fuel_1994_12_2_0_10                 2         1994
# nuclear               f1_fuel_1994_12_2_1_1                 2         1994
# oil                   f1_fuel_1994_12_6_0_2                 6         1994
# other                f1_fuel_1994_12_11_0_6                11         1994
# waste                 f1_fuel_1994_12_9_0_3                 9         1994
#
#                      plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                         rockport       ton        5377489.0
# gas                         chickasaw       mcf          40533.0
# nuclear              joseph m. farley       kgU           2260.0
# oil                      clinch river       bbl           6510.0
# other                      w.f. wyman       bbl          55652.0
# ...

# %%
#Merging in Pandas

fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True)
fuel_df2 = fuel_data.iloc[19000:].reset_index(drop=True)

# %%
print(fuel_df1)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
#check that the length of both dataframes sum to the expected length
assert len(fuel_data) == (len(fuel_df1) + len(fuel_df2))

# %%
#an inner merge will lose rows that do not match in both dataframes
pd.merge(fuel_df1, fuel_df2, how="inner")
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
#outer merge returns all rows in both dataframes
pd.merge(fuel_df1, fuel_df2, how="outer")
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
#removes rows from the right dataframe that do not have a match with the left
#and keeps all rows from the left
pd.merge(fuel_df1, fuel_df2, how="left")
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
#check for duplicate rows
fuel_data.duplicated().any()
# Out:
# False

# %%
plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
            'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})

# %%
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('fuel unit')
# Out:
# Text(0.5, 0, 'fuel unit')

# %%
#Plot barchart by taking the logarithm of the y-axis as follows:


g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
plt.show
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
# Box plot
sns.boxplot(x="fuel_type_code_pudl", y="utility_id_ferc1",
            palette=["m", "g"], data=fuel_data)

# %%
# KDE plot 
sns.kdeplot(fuel_data['fuel_cost_per_unit_burned'], shade=True, color="y")

# %%
#Select a sample of the Dataset

sample_df = fuel_data.sample(n=50, random_state=4)
sns.regplot(x=sample_df["utility_id_ferc1"], y=sample_df["fuel_cost_per_mmbtu"], fit_reg=False)

# %%
# KDE plot 
sns.kdeplot(sample_df['fuel_cost_per_unit_burned'], shade=True, color="r")

# %%
#For heatmap
